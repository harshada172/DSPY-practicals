# %% [markdown]
# # **Experiment No : 03**
# ### **Aim :** Learn basics of maplotlib library and its use as visualisation tool in data science pipeline and learn about line plots and scatter plots.

# %% [markdown]
# ### **Theory :**
# Matplotlib is a multi-platform data visualization library built on NumPy arrays, and designed to work with the broader SciPy stack.
#
# It was conceived by John Hunter in 2002, originally as a patch to IPython for enabling interactive MATLAB-style plotting via gnuplot from the IPython command line.
#
# One of Matplotlib’s most important features is its ability to play well with many operating systems and graphics backends. Matplotlib supports dozens of backends and output types, which means you can count on it to work regardless of which operating system you are using or which output format you wish.
#
# This cross-platform, everything-to-everyone approach has been one of the great strengths of Matplotlib. It has led to a large user base, which in turn has led to an active developer base and Matplotlib’s powerful tools and ubiquity within the scientific Python world.
#
# In recent years, however, the interface and style of Matplotlib have begun to show their age. Newer tools like ggplot and ggvis in the R language, along with web visualization toolkits based on D3js and HTML5 canvas, often make Matplotlib feel clunky and old-fashioned.
#
# ### **Performance :**

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.__version__
# Out:
# '3.10.0'

# %%
#setting ploting style
plt.style.use('classic')

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 1000)

fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# ### **Saving Figures to File**
# One nice feature of Matplotlib is the ability to save figures in a wide variety of formats. Saving a figure can be done using the savefig() command. For example, to save the previous figure as a PNG file, you can run this:

# %%
#Save above plot with file named my_figure.png in Current Working Directory
fig.savefig('my_figure.png')
# Cross check the folder content
# !ls -lh my_figure.png
# use Image package in python to check contents of png file in cwd
from IPython.display import Image
Image('my_figure.png')
# Out:
# -rw-r--r-- 1 root root 45K Feb 28 13:51 my_figure.png

# %%
#checking supported file types by matplotlib
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ## **Matplotlib API Interfaces**
# A potentially confusing feature of Matplotlib is its dual interfaces: a convenient MATLAB-style state-based interface, and a more powerful object-oriented interface. This section we will review them breifly.
#
# ## **MATLAB-style Interface**
# Matplotlib was originally written as a Python alternative for MATLAB users, and much of its syntax reflects that fact. The MATLAB-style tools are contained in the pyplot (plt) interface. See the example inthe code cell below.

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# This interface is stateful: It keeps track of the "current" figure and axes, which are where all plt commands are applied.
#
# You can get a reference to these using the plt.gcf() (get current figure) and plt.gca() (get current axes) routines.
#
# While this stateful interface is fast and convenient for simple plots, it is easy to run into problems.
#
# For example, once the second panel is created, how can we go back and add something to the first? This interface does have a solution but it is not a easy solution.
#
# ### **Object-oriented interface of Matplotlib**
# The object-oriented interface can nicely handle more complicated plots, and for when you want more control over your figure.
#
# Rather than depending on some notion of an "active" figure or axes, in the object-oriented interface the plotting functions are methods of explicit Figure and Axes objects.
#
# To re-create the previous plot using this style of plotting, you might do the following:

# %%
#First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# The difference is as small as switching plt.plot() to ax.plot().
#
# Now we start exploring different types of plots in following sections.
#
# ### **Simple Line Plots**
# Perhaps the simplest of all plots is the visualization of a single function y = f(x).
#
# Here we will take a first look at creating a simple plot of this type.

# %%
# Import all necesssary libraries
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# The previous style 'seaborn-whitegrid' caused an error.
# Let's check the available styles first.
print("Available Matplotlib styles:")
print(plt.style.available)

# Setting a commonly available style, for example, 'ggplot' or 'default'.
# You can choose one from the list printed above.
plt.style.use('ggplot') # Or 'default', 'classic', etc.
# Out:
# Available Matplotlib styles:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# creating objects of figure and axes.
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the figure (an instance of the class plt.Figure) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
#
# The axes (an instance of the class plt.Axes) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.
#
# Once we have created an axes, we can use the ax.plot function to plot some data.

# %%
# we will plot sine curve using ax.plot function
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %%
plt.plot(x, np.sin(x))   #shown in blue
plt.plot(x, np.sin(2*x)) #Shown in green
plt.plot(x,(x**(1/2))/2) #Shown in red

# %% [markdown]
# ### **Adjusting the Plot: Line Colors and Styles**
# The first adjustment you might wish to make to a plot is to control the line colors and styles. The plt.plot() function takes additional arguments that can be used to specify these. To adjust the color, you can use the color keyword, which accepts a string argument representing virtually any imaginable color. The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# ### **Adjusting the Plot: Axes Limits**
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control. The most basic way to adjust axis limits is to use the plt.xlim() and plt.ylim() methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
# Reverse the Axis Limit
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is plt.axis() (note here the potential confusion between axes with an e, and axis with an i). The plt.axis() method allows you to set the x and y limits with a single call, by passing a list which specifies [xmin, xmax, ymin, ymax] :

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# ### **Labeling Plots**
# As the last piece of this section, we'll briefly look at the labeling of plots: titles, axis labels, and simple legends.
#
# Titles and axis labels are the simplest such labels—there are methods that can be used to quickly set them:

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type.
#
# Again, Matplotlib has a built-in way of quickly creating such a legend. It is done via the (you guessed it) plt.legend() method.
#
# Though there are several valid ways of using this, I find it easiest to specify the label of each line using the label keyword of the plot function:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ax.set() method to set all these properties at once:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# ### **Simple Scatter Plots**
# Another commonly used plot type is the simple scatter plot, a close cousin of the line plot. Instead of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# ### **Scatter Plots with plt.scatter**
# A second, more powerful method of creating scatter plots is the plt.scatter function, which can be used very similarly to the plt.plot function:

# %%
y = np.sin(x)
plt.scatter(x, y, marker='o');

# %%
# Consider this code for scatter plot

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %% [markdown]
# ## **Question Answer Section**
# ### **1. List any 2 python APIs that are used for Plotting Graphs.**
#
# Two commonly used Python APIs for plotting graphs are:
#
# Matplotlib: This is the foundational plotting library in Python, offering extensive control over every aspect of a figure. Most other plotting libraries are built on top of Matplotlib.
# Seaborn: This library is built on Matplotlib and provides a high-level interface for drawing attractive and informative statistical graphics. It simplifies the process of creating complex visualizations.
#
# ### **2. Name 2 important machnisms used for accesssing Matplotlib API.**
#
# 1. **MATLAB-style Interface:** This is a state-based interface, often accessed through matplotlib.pyplot (imported as plt). It's convenient for simple plots but can be less flexible for complex visualizations.
# 2. **Object-oriented Interface:** This provides more control over your figures and axes. You explicitly create Figure and Axes objects and then call plotting methods directly on these objects (e.g., ax.plot()). This is generally preferred for more complex and customized plots.
#
# ### **3. Create a collection of 100 random normal numbers with parameter mean 30, sd 4 store it in object summer_temp**

# %%
# Create a collection of 100 random normal numbers
# with a mean of 30 and standard deviation of 4
summer_temp = np.random.normal(loc=30, scale=4, size=100)

# Display the first few values to verify
print(summer_temp[:10])

# Also print some statistics to confirm mean and std
print(f"Mean of summer_temp: {np.mean(summer_temp):.2f}")
print(f"Standard deviation of summer_temp: {np.std(summer_temp):.2f}")
# Out:
# [25.54199892 29.20546314 28.78067152 30.61553921 29.57250404 30.28792929
#  24.80816228 33.04403814 26.52682555 36.38815674]
# Mean of summer_temp: 29.97
# Standard deviation of summer_temp: 3.49

# %% [markdown]
# ### **4. Sort above set and store in objrct sorted_summer_temp**

# %%
# Sort the summer_temp array
sorted_summer_temp = np.sort(summer_temp)

# Display the first few values to verify sorting
print("First 10 sorted temperatures:")
print(sorted_summer_temp[:10])

# Display the last few values to verify sorting
print("Last 10 sorted temperatures:")
print(sorted_summer_temp[-10:])
# Out:
# First 10 sorted temperatures:
# [22.16856503 22.43063494 22.635205   23.29162476 23.38073775 24.42267425
#  24.63289888 24.80816228 25.1613397  25.40114123]
# Last 10 sorted temperatures:
# [34.30353831 34.35656491 34.39979149 34.84220216 35.50059942 35.59945329
#  36.2765082  36.38815674 36.44260694 38.78918768]

# %% [markdown]
# ### **5. Store average of 25 consecutive elements from sorted_summer_temp into object x and plot it as a line plot. What kind of information do u get about the data?**

# %% [markdown]
# # Task
# We will first calculate the moving average of the `sorted_summer_temp` array, store the result in an object named `x`, and then generate a line plot of `x` with appropriate labels and a title. Finally, I will analyze the plot to describe the information it conveys about the data.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Assuming sorted_summer_temp is already available from previous execution
# # if 'sorted_summer_temp' not in globals():
# #     # This part is for standalone testing, not needed if executed sequentially in Colab
# #     summer_temp = np.random.normal(loc=30, scale=4, size=100)
# #     sorted_summer_temp = np.sort(summer_temp)
#
# # 1. Calculate the average of every 25 consecutive elements from sorted_summer_temp
# window_size = 25
# # Use a convolution to efficiently calculate the moving average
# weights = np.ones(window_size) / window_size
# x = np.convolve(sorted_summer_temp, weights, mode='valid')
#
# print(f"Number of moving averages calculated: {len(x)}")
# print("First 5 moving averages:", x[:5])
# print("Last 5 moving averages:", x[-5:])
#
# # 2. Plot the moving averages
# plt.figure(figsize=(12, 7))
# plt.plot(x, color='skyblue', linewidth=2)
# plt.title('Moving Average of Sorted Summer Temperatures (Window Size = 25)', fontsize=16)
# plt.xlabel('Moving Average Index', fontsize=12)
# plt.ylabel('Average Temperature (°C)', fontsize=12)
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.show()
#
# # 3. Interpret the data from the plot
# print("\n--- Interpretation of the Moving Average Plot ---")
# print("The plot shows the moving average of the `sorted_summer_temp` data with a window size of 25.")
# print("Since the original `sorted_summer_temp` array was sorted in ascending order,")
# print("the moving average plot consistently displays an increasing trend.")
# print("This indicates that as we move through the sorted temperature data, the average temperature within each consecutive 25-element window also generally increases.")
# print("The line plot provides a smoothed view of the data's overall upward progression,")
# print("filtering out individual variations and highlighting the underlying trend of the sorted temperatures.")
# print("Specifically, it shows how the average temperature shifts from the lower end to the higher end of the sorted range.")
# ```

# %% [markdown]
# ## Calculate Moving Averages
#
# ### Subtask:
# Calculate the average of every 25 consecutive elements from the `sorted_summer_temp` array. Store these averages in a new object named `x`.

# %% [markdown]
# **Reasoning**:
# To calculate the moving average as specified, I will define the window size, create the corresponding weights, and then use `np.convolve` to apply these weights to `sorted_summer_temp`, storing the result in `x`.

# %%
window_size = 25
weights = np.ones(window_size) / window_size

x = np.convolve(sorted_summer_temp, weights, mode='valid')

print(f"Number of calculated moving averages (length of x): {len(x)}")
print(f"First 5 elements of x: {x[:5]}")
print(f"Last 5 elements of x: {x[-5:]}")
# Out:
# Number of calculated moving averages (length of x): 76
# First 5 elements of x: [25.44208319 25.64329219 25.83429167 26.01940156 26.18631114]
# Last 5 elements of x: [33.63417895 33.78779263 33.94569082 34.10518295 34.35544307]

# %% [markdown]
# **Reasoning**:
# Now that the moving averages are calculated and stored in `x`, I will plot `x` as a line plot to visualize the trend, adding appropriate labels and a title for clarity.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 7))
plt.plot(x, color='skyblue', linewidth=2)
plt.title('Moving Average of Sorted Summer Temperatures (Window Size = 25)', fontsize=16)
plt.xlabel('Moving Average Index', fontsize=12)
plt.ylabel('Average Temperature (°C)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Interpretation of the Moving Average Plot
#
# The line plot displays the moving average of the `sorted_summer_temp` data with a window size of 25. Since `sorted_summer_temp` was explicitly sorted in ascending order, the moving average plot consistently shows an increasing trend.
#
# This trend indicates that as we progress through the sorted temperature data, the average temperature within each consecutive 25-element window generally increases. The plot effectively smooths out any minor fluctuations, highlighting the overall upward progression of temperatures from the lowest values to the highest. It visually confirms the sorting of the original data and shows how the central tendency (average) of the temperatures changes across the range of the dataset.

# %% [markdown]
# ## Interpret Data from Plot
#
# ### Subtask:
# Analyze the generated line plot to describe the information it conveys about the `sorted_summer_temp` data, particularly focusing on trends or distribution patterns.

# %% [markdown]
# ### Interpretation of the Moving Average Plot
#
# 1.  **Overall Trend**: The line plot of the moving averages clearly shows a consistent upward or increasing trend from left to right.
# 2.  **Impact of Sorted Data**: Since the `sorted_summer_temp` array was explicitly sorted in ascending order, it is expected that the moving average of consecutive elements will also generally increase. The plot confirms this, as each subsequent window of 25 elements, when averaged, yields a higher value than the preceding one.
# 3.  **Distribution and Progression of Temperatures**: The plot reveals how the average temperature progresses through the sorted dataset. It starts with lower average temperatures (corresponding to the cooler end of the sorted distribution) and steadily rises, indicating the transition towards higher average temperatures (corresponding to the warmer end of the sorted distribution). This visual representation smooths out the individual temperature values and provides a clear picture of the temperature range from the coldest to the warmest within the dataset.
# 4.  **Smoothing Effect of Moving Average**: The moving average effectively smooths out any minor fluctuations that might be present if we were to plot the individual sorted temperatures directly. By averaging over a window of 25 elements, the plot emphasizes the underlying, monotonic increase in temperature, making the overall trend more apparent and easier to interpret. It highlights the general upward progression of temperatures rather than focusing on small, isolated variations.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the results, including the generated plot and the insights derived from it, addressing the user's query comprehensively.

# %% [markdown]
# ### **6. Repeat above step for summer_temp, store summary in object y and this time use scatter plot to plot values. What kind of information do u get about the data?**

# %% [markdown]
# # Task
# Calculate the average of every 25 consecutive elements from the original `summer_temp` array, storing these averages in a new object named `y`. Then, generate a scatter plot of `y` with a title and appropriate x and y-axis labels, and analyze the plot to describe the information it conveys about the `summer_temp` data, including trends and distribution patterns, and how it compares to the previously sorted data's line plot. Finally, summarize the results, including the scatter plot and the derived insights.

# %% [markdown]
# ## Calculate Moving Averages for summer_temp
#
# ### Subtask:
# Calculate the average of every 25 consecutive elements from the original `summer_temp` array. Store these averages in a new object named `y`.

# %% [markdown]
# **Reasoning**:
# To calculate the moving average of the `summer_temp` array as specified, I will define the window size, create the corresponding weights, use `np.convolve` to compute the moving averages, and store the result in `y`. Finally, I will print verification details as requested.

# %%
window_size = 25
weights = np.ones(window_size) / window_size

y = np.convolve(summer_temp, weights, mode='valid')

print(f"Number of calculated moving averages (length of y): {len(y)}")
print(f"First 5 elements of y: {y[:5]}")
print(f"Last 5 elements of y: {y[-5:]}")
# Out:
# Number of calculated moving averages (length of y): 76
# First 5 elements of y: [29.6802026  30.10958297 30.36138842 30.10738696 29.91290654]
# Last 5 elements of y: [30.40436639 30.55024795 30.52618567 30.2884601  30.35835688]

# %% [markdown]
# **Reasoning**:
# Now that the moving averages are calculated and stored in `y`, I will plot `y` as a scatter plot to visualize the trend, adding appropriate labels and a title for clarity.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 7))
plt.scatter(range(len(y)), y, color='salmon', alpha=0.7)
plt.title('Moving Average of Original Summer Temperatures (Window Size = 25)', fontsize=16)
plt.xlabel('Moving Average Index', fontsize=12)
plt.ylabel('Average Temperature (°C)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Interpretation of the Moving Average Scatter Plot for Original Data
#
# The scatter plot displays the moving average of the *original* `summer_temp` data (which was not sorted) with a window size of 25. Unlike the previous line plot of `sorted_summer_temp` which showed a clear increasing trend, this scatter plot reveals a different pattern:
#
# 1.  **Fluctuating Trend**: The points in the scatter plot do not show a monotonic increase or decrease. Instead, they fluctuate around a central value, which is close to the mean of the original `summer_temp` data (approximately 30°C).
# 2.  **Absence of Clear Ordering**: Because the `summer_temp` array was not sorted before calculating the moving averages, the `Moving Average Index` on the x-axis does not represent an ordered progression of temperature values. Instead, it represents the sequence of the moving averages as they were calculated from the original, randomly ordered data.
# 3.  **Smoothing Effect with Variability**: The moving average still provides a smoothing effect, reducing the noise from individual temperature fluctuations. However, because the underlying data is not sorted, the moving averages themselves still exhibit variability. This is evident in the spread of the points, indicating that consecutive windows of 25 elements in the original, unsorted data can have varying average temperatures.
# 4.  **Information about Randomness**: This plot conveys that the original `summer_temp` data, being a collection of random normal numbers, does not have an inherent ordered trend. The moving averages reflect this randomness by showing variations rather than a consistent upward or downward slope. It illustrates the distribution of average temperatures within various contiguous segments of the unsorted dataset.
#
# **Comparison with Sorted Data's Plot**:
#
# *   **Sorted Data (Line Plot)**: Showed a clear, monotonic increasing trend, confirming the sorting and highlighting the progression from lower to higher temperatures.
# *   **Original Data (Scatter Plot)**: Shows a fluctuating, relatively stable trend around the mean, reflecting the random nature of the original data. The scatter plot allows us to see the individual data points of the moving averages, emphasizing their variability.

# %% [markdown]
# ## Summary of Results for Question 6
#
# For **Question 6**, we performed the following steps on the *original* `summer_temp` data:
#
# 1.  **Calculated Moving Averages**: We computed the average of every 25 consecutive elements from the `summer_temp` array, storing these averages in an object named `y`. The calculation yielded 76 moving average values, which are:
#     *   First 5 elements of y: `[29.6802026 , 30.10958297, 30.36138842, 30.10738696, 29.91290654]`
#     *   Last 5 elements of y: `[30.40436639, 30.55024795, 30.52618567, 30.2884601 , 30.35835688]`
#
# 2.  **Generated Scatter Plot**: A scatter plot of these moving averages (`y`) was created, with 'Moving Average Index' on the x-axis and 'Average Temperature (°C)' on the y-axis. The plot included a title, axis labels, and a grid for clarity.
#
# ### Information Conveyed by the Scatter Plot:
#
# *   **Fluctuating Trend**: Unlike the line plot of the *sorted* data, this scatter plot does not show a clear monotonic trend. Instead, the points fluctuate around the mean of the original `summer_temp` data (which is approximately 30°C).
# *   **Absence of Order**: Since the `summer_temp` array was not sorted, the `Moving Average Index` on the x-axis simply represents the order in which the moving averages were calculated from the original, randomly ordered data, rather than an ordered progression of temperature values.
# *   **Variability of Averages**: The scatter plot demonstrates that even with a smoothing window of 25, the moving averages from the unsorted random data still exhibit variability. This is expected, as the underlying data is random and not inherently ordered.
# *   **Nature of Random Data**: The plot effectively illustrates that `summer_temp`, being a collection of random normal numbers, lacks an inherent ordered trend. The moving averages reflect this randomness, showing variations rather than a consistent slope.
#
# ### Comparison with Sorted Data's Plot (Question 5):
#
# *   **Sorted Data (Line Plot)**: The line plot for `sorted_summer_temp` showed a clear, monotonic increasing trend. This was a direct consequence of sorting the data, which highlighted the progression from the lowest to the highest temperatures.
# *   **Original Data (Scatter Plot)**: The scatter plot for `summer_temp` shows a fluctuating, relatively stable distribution of moving averages around the mean. This reflects the random nature of the original data and the lack of a predetermined order. The scatter plot allows us to visualize the spread and individual points of these averages, emphasizing their variation around the central tendency.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Summarize the results, including the generated plot and the insights derived from it, addressing the user's query comprehensively.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# 1.  **What information does the scatter plot convey about the `summer_temp` data, including trends and distribution patterns?**
#     The scatter plot of the moving averages for the *original* `summer_temp` data reveals a fluctuating trend around a central value, approximately 30°C. It demonstrates an absence of clear ordering, as the x-axis represents the calculation sequence rather than an ordered progression of temperature values. The plot highlights the variability of averages, indicating that even with a smoothing window of 25, averages from unsorted random data still show variation. It effectively illustrates that the original `summer_temp` data, being a collection of random normal numbers, lacks an inherent ordered trend.
#
# 2.  **How does it compare to the previously sorted data's line plot?**
#     In stark contrast to the line plot of the *sorted* `summer_temp` data, which showed a clear, monotonic increasing trend, this scatter plot for the original data exhibits a fluctuating, relatively stable distribution of moving averages around the mean. The sorted data's plot confirmed the sorting and highlighted a progression from lower to higher temperatures, whereas the original data's plot reflects the random nature and lack of predetermined order in the raw dataset.
#
# ### Data Analysis Key Findings
# *   A total of 76 moving average values were calculated from the original `summer_temp` array using a window size of 25.
# *   The first five moving averages were approximately `[29.68, 30.11, 30.36, 30.11, 29.91]`, and the last five were `[30.40, 30.55, 30.53, 30.29, 30.36]`.
# *   The scatter plot of these moving averages shows that the values fluctuate around an approximate mean of 30°C, indicating no clear increasing or decreasing trend in the original, unsorted data.
# *   The scatter plot visually confirms the random nature of the original `summer_temp` data, as the moving averages do not follow any ordered progression and still exhibit variability despite the smoothing effect.
#
# ### Insights or Next Steps
# *   Applying moving averages to raw, unsorted data helps to smooth out noise and reveal underlying patterns or lack thereof, confirming the inherent randomness when no clear trend emerges.
# *   Further analysis could involve comparing moving averages with different window sizes to observe their impact on smoothing and variability, or exploring other statistical measures to characterize the distribution of the original `summer_temp` data more deeply.

# %% [markdown]
# ### **7. plot summer_temp and y together in same line plot.**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure summer_temp and y are available. If not, this is a safeguard.
# In this execution context, they are available from previous steps.
if 'summer_temp' not in globals():
    print("Warning: 'summer_temp' not found, generating dummy data.")
    summer_temp = np.random.normal(loc=30, scale=4, size=100)
    window_size = 25
    weights = np.ones(window_size) / window_size
    y = np.convolve(summer_temp, weights, mode='valid')
elif 'y' not in globals():
    print("Warning: 'y' (moving average) not found, calculating it now.")
    window_size = 25
    weights = np.ones(window_size) / window_size
    y = np.convolve(summer_temp, weights, mode='valid')

plt.figure(figsize=(14, 8))

# Plot original summer_temp
plt.plot(range(len(summer_temp)), summer_temp, label='Original Summer Temperatures', alpha=0.7, color='lightgray')

# Plot the moving average 'y'
# To align 'y' with the original data, we can plot it against indices shifted by half the window size.
# However, for simplicity and direct observation of smoothing, we'll plot it over its own range.
# If we want to align to the center of the window:
# x_y = np.arange(len(y)) + window_size / 2 - 0.5
# plt.plot(x_y, y, label=f'Moving Average (Window {window_size})', color='darkorange', linewidth=2)

plt.plot(range(len(y)), y, label=f'Moving Average (Window {window_size})', color='darkorange', linewidth=2)


plt.title('Original Summer Temperatures vs. Moving Average', fontsize=16)
plt.xlabel('Data Point Index', fontsize=12)
plt.ylabel('Temperature (°C)', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Conclusion**
# Thus we have learned abou basics of ploting using matplotlib.
